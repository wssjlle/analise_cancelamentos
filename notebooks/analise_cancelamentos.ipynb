# %% [markdown]
# # 📊 Análise de Cancelamentos de Clientes (Churn Analysis)
#
# ## Visão Geral do Projeto
#
# Este notebook apresenta uma análise exploratória de dados (EDA) completa para entender os padrões e causas de cancelamento de serviços em uma base de clientes.
#
# ### Objetivos
# - Identificar padrões de comportamento de clientes que cancelam
# - Analisar o impacto de diferentes variáveis no cancelamento
# - Gerar insights acionáveis para reduzir a taxa de churn
# - Desenvolver visualizações profissionais para apresentação de resultados
#
# ### Estrutura da Análise
# 1. **Importação e Configuração** - Carregamento de bibliotecas e dados
# 2. **Exploração Inicial** - Visualização e entendimento da estrutura dos dados
# 3. **Limpeza e Preparação** - Tratamento de valores ausentes e inconsistências
# 4. **Análise Descritiva** - Estatísticas e distribuições das variáveis
# 5. **Análise de Churn** - Taxas de cancelamento e segmentação
# 6. **Análise Multivariada** - Relações entre variáveis e cancelamento
# 7. **Insights e Recomendações** - Conclusões e ações sugeridas

# %% [markdown]
# ---
# ## 1. Importação e Configuração

# %%
# Importação de bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
import os

# Configurações para reprodutibilidade e qualidade
np.random.seed(42)
warnings.filterwarnings('ignore')

# Configurações de estilo para visualizações
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# Configurações para Plotly
px.defaults.template = "plotly_white"
px.defaults.color_discrete_sequence = px.colors.qualitative.Set2

print("✅ Bibliotecas carregadas com sucesso!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")

# %%
# Carregamento da base de dados
DATA_PATH = "../data/raw/cancelamentos_sample.csv"

try:
    df = pd.read_csv(DATA_PATH)
    print(f"✅ Dados carregados com sucesso!")
    print(f"📊 Dimensões do dataset: {df.shape[0]} linhas x {df.shape[1]} colunas")
except FileNotFoundError:
    print(f"❌ Erro: Arquivo não encontrado em {DATA_PATH}")
    print("Verifique se o arquivo existe e o caminho está correto.")
except Exception as e:
    print(f"❌ Erro ao carregar dados: {e}")
